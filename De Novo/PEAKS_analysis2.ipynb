# %%
import os
import pandas as pd
import numpy as np

# %%
#work with p30_5 first

iden = pd.read_excel(
    'p30_5_id.xlsx',
    index_col=0
)

unid = pd.read_excel(
    'p30_5_unid.xlsx',
    index_col=0
)

par = pd.read_excel(
    'p30_5_partialclust.xlsx',
    index_col=0
)

mis = pd.read_excel(
    'p30_5_mismatchclust.xlsx',
    index_col=0
)

# %%
iden
# Out:
#        Peptide           Spectrum  File  Length  PEPscore       FDR     Delta  \
# 0    AEEPNAAVP  AB15_HORMAD_76046  AB15       9  0.002901  0.000930  0.512174
# 1    AEEPNAAVP        AB18_105156  AB18       9  0.012526  0.000295  0.647181
# 2    AEEPNAAVP         AB16_13508  AB16       9  0.001668  0.000265  0.405454
# 3    AEEPNAAVP         AB16_13646  AB16       9  0.002381  0.000265  0.691826
# 4    AEEPNAAVP  20220420_MM_11120  MM01       9  0.001815  0.000553  0.631415
# ..         ...                ...   ...     ...       ...       ...       ...
# 246   DEQQVNVL        AB18_110462  AB18       8  0.005966  0.000295  0.884598
# 247   DEQQVNVL        AB19_218688  AB19       8  0.002861  0.000139  0.980161
# 248   DEQQVNVL        AB19_261276  AB19       8  0.006828  0.000139  0.680484
# 249   DEQQVNVL  20220420_MM_13594  MM01       8  0.021602  0.001514  0.978398
# 250   DEQQVNVL  20220420_ZK_15014  ZK01       8  0.028555  0.001627  0.931146
#
# ...

# %%
#load the peaks files

deepnovo = pd.read_csv(
    'alldeepnovo.csv'
)

peptide = pd.read_csv(
    'allpeptide.csv'
)

psms = pd.read_csv(
    'allpsms.csv'
).drop(columns='Unnamed: 0')

# %%
#merging them for psms

A = psms
B = unid[['Spectrum_ID','File','Cluster_ID']]
C = par[['Spectrum_ID','File','Cluster_ID']]
D = mis[['Spectrum_ID','File','Cluster_ID']]
E = iden[['Spectrum_ID','File','Cluster_ID']]

unid_psms = pd.merge(
    A,
    B,
    how = 'right',
    on = ['Spectrum_ID', 'File']
)

par_psms = pd.merge(
    A,
    C,
    how = 'right',
    on = ['Spectrum_ID', 'File']
)

mis_psms = pd.merge(
    A,
    D,
    how = 'right',
    on = ['Spectrum_ID', 'File']
)

iden_psms = pd.merge(
    A,
    E,
    how = 'right',
    on = ['Spectrum_ID', 'File']
)

# %%
iden_psms.to_excel('iden_p30_5.xlsx')
mis_psms.to_excel('mismatch_p30_5.xlsx')
par_psms.to_excel('partial_p30_5.xlsx')
unid_psms.to_excel('unid_p30_5.xlsx')

# %%
#check with the p30_6 files one

iden = pd.read_excel(
    'p30_6_id.xlsx',
    index_col=0
)

unid = pd.read_excel(
    'p30_6_unid.xlsx',
    index_col=0
)

par = pd.read_excel(
    'p30_6_partialclust.xlsx',
    index_col=0
)

mis = pd.read_excel(
    'p30_6_mismatchclust.xlsx',
    index_col=0
)

A = psms
B = unid[['Spectrum_ID','File','Cluster_ID']]
C = par[['Spectrum_ID','File','Cluster_ID']]
D = mis[['Spectrum_ID','File','Cluster_ID']]
E = iden[['Spectrum_ID','File','Cluster_ID']]

unid_psms = pd.merge(
    A,
    B,
    how = 'right',
    on = ['Spectrum_ID', 'File']
)

par_psms = pd.merge(
    A,
    C,
    how = 'right',
    on = ['Spectrum_ID', 'File']
)

mis_psms = pd.merge(
    A,
    D,
    how = 'right',
    on = ['Spectrum_ID', 'File']
)

iden_psms = pd.merge(
    A,
    E,
    how = 'right',
    on = ['Spectrum_ID', 'File']
)

# %%
iden_psms.to_excel('iden_p30_6.xlsx')
mis_psms.to_excel('mismatch_p30_6.xlsx')
par_psms.to_excel('partial_p30_6.xlsx')
unid_psms.to_excel('unid_p30_6.xlsx')

# %%
#check with the p30_4 files one

iden = pd.read_excel(
    'p30_4_id.xlsx',
    index_col=0
)

unid = pd.read_excel(
    'p30_4_unid.xlsx',
    index_col=0
)

par = pd.read_excel(
    'p30_4_partialclust.xlsx',
    index_col=0
)

mis = pd.read_excel(
    'p30_4_mismatchclust.xlsx',
    index_col=0
)


A = psms
B = unid[['Spectrum_ID','File','Cluster_ID']]
C = par[['Spectrum_ID','File','Cluster_ID']]
D = mis[['Spectrum_ID','File','Cluster_ID']]
E = iden[['Spectrum_ID','File','Cluster_ID']]

unid_psms = pd.merge(
    A,
    B,
    how = 'right',
    on = ['Spectrum_ID', 'File']
)

par_psms = pd.merge(
    A,
    C,
    how = 'right',
    on = ['Spectrum_ID', 'File']
)

mis_psms = pd.merge(
    A,
    D,
    how = 'right',
    on = ['Spectrum_ID', 'File']
)

iden_psms = pd.merge(
    A,
    E,
    how = 'right',
    on = ['Spectrum_ID', 'File']
)

# %%
iden_psms.to_excel('iden_p30_4.xlsx')
mis_psms.to_excel('mismatch_p30_4.xlsx')
par_psms.to_excel('partial_p30_4.xlsx')
unid_psms.to_excel('unid_p30_4.xlsx')
